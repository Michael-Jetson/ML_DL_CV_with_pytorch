# %%
import torch

# %%
import matplotlib as mpl

# %%
x=range(1,20)
y=range(5,24)
from matplotlib import pyplot as plt

# %% [markdown]
# 注意一下，plt.plot输入的x和y需要保证维数一致

# %%
plt.plot(x,y)
plt.show()

# %%
y
# Out:
# range(5, 24)

# %%
print(y)
# Out:
# range(5, 24)

# %%
z=(10,11.5,12,14,16,11,18,19,20,21,17,16,15,13,11,10.5,10.2,10,9)
len(z)
# Out:
# 19

# %%
plt.plot(x,z)

# %%
x=range(1,6)
y=range(1,6)
labels=("One","Two","Three","Hello","Go")
plt.plot(x,y,label="hello")
plt.xticks(x,labels,rotation=45)
plt.xlabel("x-axis",fontsize=10,labelpad=100,loc='right')
plt.grid(alpha=0.2)
plt.legend()
plt.show()
